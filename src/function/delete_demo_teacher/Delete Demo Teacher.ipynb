# %%
import main
func = main.DeleteDemoTeacher()

# %%
event = {'profile_name': 'dev', 'path': 'test', 'pathParameters': {'name': 'Tim'}}

# %%
func(event, None)
# Out:
# INFO:root:Call to Lambda: DeleteDemoTeacher
# INFO:root:Event:
# INFO:root:{'path': 'test', 'profile_name': 'dev', 'pathParameters': {'name': 'Tim'}}
# INFO:root:Context:
# INFO:root:None
# INFO:root:Path: 'test'
# INFO:botocore.credentials:Found credentials in shared credentials file: ~/.aws/credentials
# INFO:root:[{'username': 'DAGWKO', 'displayName': 'Tim', 'schoolName': 'School', 'lastSeenInApp': '2019-04-15 10:17:06', 'demo': True, 'created': '2019-02-20 10:04:09', 'phone': 'Tim', 'lastSeen': '2019-04-18 06:13:45', 'groups': ['LMSTeacher'], 'lastSeenMS': 1555568025721, 'credentials': {'SecretKey': '90cu3v4a2MGAVjt/jlvqbqMiiC08I3uF2yVeq5nq', 'AccessKeyId': 'ASIAYVK7R2ZEZIBAMVPM', 'Expiration': {}, 'SessionToken': '...'}, 'lastSeenInAppMS': 1555323426356, 'schoolGroupName': 'Group', 'salt': '000000', 'createdMS': 1550657049862, 'hash': '071d83ce3b57f6e85c62e127509576455d29404d8a84f660d344943d9abedc90de739ea289add2f04d3a06f21a46dfde95ff684dea9da7f5a3cf126d4baa7f6f'}]
# ...
